# %% [markdown]
# Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())  # Menggunakan copy agar data asli tidak berubah

print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Insertion Sort

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())

print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# Merge Sort

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# Tugas Rombel 03

# %%
def urutkan_nilai_mahasiswa(daftar_nilai):
    if len(daftar_nilai) <= 1:
        return daftar_nilai

    # Memilih pivot (nilai tengah)
    pivot = daftar_nilai[len(daftar_nilai) // 2]

    # Membagi daftar menjadi tiga bagian untuk urutan Descending (Tinggi ke Rendah):
    # 1. Nilai yang lebih besar dari pivot (di sebelah kiri)
    # 2. Nilai yang sama dengan pivot (di tengah)
    # 3. Nilai yang lebih kecil dari pivot (di sebelah kanan)
    lebih_besar = [x for x in daftar_nilai if x > pivot]
    sama_dengan = [x for x in daftar_nilai if x == pivot]
    lebih_kecil = [x for x in daftar_nilai if x < pivot]

    return urutkan_nilai_mahasiswa(lebih_besar) + sama_dengan + urutkan_nilai_mahasiswa(lebih_kecil)

# Contoh Data Nilai Mahasiswa
nilai_mahasiswa = [78, 92, 85, 60, 95, 88, 72, 85, 100, 65]
# Proses Pengurutan
peringkat = urutkan_nilai_mahasiswa(nilai_mahasiswa)

# Output Hasil
print("=== DAFTAR PERINGKAT NILAI MAHASISWA ===")
print("Data Asli   :", nilai_mahasiswa)
print("Hasil Urut  :", peringkat)
print("-" * 40)

# Menampilkan Peringkat
print(f"Peringkat 1 : {peringkat[0]}")
print(f"Peringkat 2 : {peringkat[1]}")
print(f"Peringkat 3 : {peringkat[2]}")
print(f"Peringkat 4 : {peringkat[3]}")
print(f"Peringkat 5 : {peringkat[4]}")
print(f"Peringkat 6 : {peringkat[5]}")
print(f"Peringkat 7 : {peringkat[6]}")
print(f"Peringkat 8 : {peringkat[7]}")
print(f"Peringkat 9 : {peringkat[8]}")
print(f"Peringkat 10 : {peringkat[9]}")
# Out:
# === DAFTAR PERINGKAT NILAI MAHASISWA ===
# Data Asli   : [78, 92, 85, 60, 95, 88, 72, 85, 100, 65]
# Hasil Urut  : [100, 95, 92, 88, 85, 85, 78, 72, 65, 60]
# ----------------------------------------
# Peringkat 1 : 100
# Peringkat 2 : 95
# Peringkat 3 : 92
# Peringkat 4 : 88
# Peringkat 5 : 85
# Peringkat 6 : 85
# Peringkat 7 : 78
# Peringkat 8 : 72
# Peringkat 9 : 65
# Peringkat 10 : 60
